# %%
#Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np

#Upload from csv
data_set_path = "school_attendance.csv"

#Read data and results
data_set_df = pd.read_csv(data_set_path)

data_set_df.head(50)
# Out:
#    District code            District name                    Category  \
# 0        00000CT              Connecticut                         NaN
# 1        00000CT              Connecticut                Homelessness
# 2        00000CT              Connecticut  Students With Disabilities
# 3        00000CT              Connecticut          Free/Reduced Lunch
# 4        00000CT              Connecticut          Free/Reduced Lunch
# 5        00000CT              Connecticut          Free/Reduced Lunch
# 6        00000CT              Connecticut            English Learners
# 7        00000CT              Connecticut              Race/Ethnicity
# 8        00000CT              Connecticut              Race/Ethnicity
# 9        00000CT              Connecticut              Race/Ethnicity
# 10       00000CT              Connecticut              Race/Ethnicity
# 11       00000CT              Connecticut                  High Needs
# 12       00000CT              Connecticut                  High Needs
# 13       0010011  Andover School District                         NaN
# 14       0010011  Andover School District  Students With Disabilities
# 15       0010011  Andover School District          Free/Reduced Lunch
# 16       0010011  Andover School District              Race/Ethnicity
# 17       0010011  Andover School District                  High Needs
# 18       0010011  Andover School District                  High Needs
# 19       0020011  Ansonia School District                         NaN
# 20       0020011  Ansonia School District  Students With Disabilities
# 21       0020011  Ansonia School District          Free/Reduced Lunch
# 22       0020011  Ansonia School District          Free/Reduced Lunch
# 23       0020011  Ansonia School District          Free/Reduced Lunch
# 24       0020011  Ansonia School District            English Learners
# 25       0020011  Ansonia School District              Race/Ethnicity
# 26       0020011  Ansonia School District              Race/Ethnicity
# 27       0020011  Ansonia School District              Race/Ethnicity
# 28       0020011  Ansonia School District              Race/Ethnicity
# 29       0020011  Ansonia School District                  High Needs
# 30       0020011  Ansonia School District                  High Needs
# 31       0030011  Ashford School District                         NaN
# 32       0030011  Ashford School District  Students With Disabilities
# 33       0030011  Ashford School District          Free/Reduced Lunch
# 34       0030011  Ashford School District          Free/Reduced Lunch
# 35       0030011  Ashford School District          Free/Reduced Lunch
# 36       0030011  Ashford School District              Race/Ethnicity
# 37       0030011  Ashford School District              Race/Ethnicity
# 38       0030011  Ashford School District                  High Needs
# 39       0030011  Ashford School District                  High Needs
# 40       0040011     Avon School District                         NaN
# 41       0040011     Avon School District  Students With Disabilities
# 42       0040011     Avon School District          Free/Reduced Lunch
# 43       0040011     Avon School District          Free/Reduced Lunch
# 44       0040011     Avon School District          Free/Reduced Lunch
# 45       0040011     Avon School District            English Learners
# 46       0040011     Avon School District              Race/Ethnicity
# 47       0040011     Avon School District              Race/Ethnicity
# 48       0040011     Avon School District              Race/Ethnicity
# 49       0040011     Avon School District              Race/Ethnicity
#
#                          Student group  \
# 0                         All Students
# 1   Students Experiencing Homelessness
# 2           Students With Disabilities
# 3                   Free Meal Eligible
# 4          Reduced Price Meal Eligible
# 5     Free/Reduced Price Meal Eligible
# 6                     English Learners
# 7                      All other races
# 8            Black or African American
# 9          Hispanic/Latino of any race
# 10                               White
# 11         Students Without High Needs
# 12            Students With High Needs
# 13                        All Students
# 14          Students With Disabilities
# 15    Free/Reduced Price Meal Eligible
# 16                               White
# 17         Students Without High Needs
# 18            Students With High Needs
# 19                        All Students
# 20          Students With Disabilities
# 21                  Free Meal Eligible
# 22         Reduced Price Meal Eligible
# 23    Free/Reduced Price Meal Eligible
# 24                    English Learners
# 25                     All other races
# 26           Black or African American
# 27         Hispanic/Latino of any race
# 28                               White
# 29         Students Without High Needs
# 30            Students With High Needs
# 31                        All Students
# 32          Students With Disabilities
# 33                  Free Meal Eligible
# 34         Reduced Price Meal Eligible
# 35    Free/Reduced Price Meal Eligible
# 36         Hispanic/Latino of any race
# 37                               White
# 38         Students Without High Needs
# 39            Students With High Needs
# 40                        All Students
# 41          Students With Disabilities
# 42                  Free Meal Eligible
# 43         Reduced Price Meal Eligible
# 44    Free/Reduced Price Meal Eligible
# 45                    English Learners
# 46                     All other races
# 47           Black or African American
# 48         Hispanic/Latino of any race
# 49                               White
#
#     2021-2022 student count - year to date  \
# 0                                   500285
# 1                                     1814
# 2                                    78417
# 3                                   168984
# 4                                    29905
# 5                                   198889
# 6                                    43571
# 7                                    48700
# 8                                    63099
# 9                                   146298
# 10                                  242188
# 11                                  241106
# 12                                  248239
# 13                                     161
# 14                                      23
# 15                                      30
# 16                                     134
# 17                                     113
# 18                                      48
# 19                                    2139
# 20                                     369
# 21                                    1192
# 22                                     225
# 23                                    1417
# 24                                     122
# 25                                     149
# 26                                     434
# 27                                     987
# 28                                     569
# 29                                     528
# 30                                    1545
# 31                                     343
# 32                                      46
# 33                                      92
# 34                                      21
# 35                                     113
# 36                                      31
# 37                                     283
# 38                                     189
# 39                                     145
# 40                                    3057
# 41                                     324
# 42                                     226
# 43                                      60
# 44                                     286
# 45                                      76
# 46                                     712
# 47                                     179
# 48                                     221
# 49                                    1945
#
#     2021-2022 attendance rate - year to date  2020-2021 student count  \
# 0                                     0.9169                 496092.0
# 1                                     0.8348                   1735.0
# 2                                     0.8899                  76487.0
# 3                                     0.8851                 176225.0
# 4                                     0.9184                  30886.0
# 5                                     0.8901                 207111.0
# 6                                     0.8976                  40619.0
# 7                                     0.9314                  47339.0
# 8                                     0.8941                  62267.0
# 9                                     0.8935                 138260.0
# 10                                    0.9338                 248226.0
# 11                                    0.9398                 236395.0
# 12                                    0.8954                 251220.0
# 13                                    0.9386                    144.0
# 14                                    0.9315                      NaN
# 15                                    0.9274                     31.0
# 16                                    0.9365                    115.0
# 17                                    0.9410                    100.0
# 18                                    0.9328                     44.0
# 19                                    0.9045                   2153.0
# 20                                    0.8897                    394.0
# 21                                    0.8893                   1217.0
# 22                                    0.9282                    213.0
# 23                                    0.8953                   1430.0
# 24                                    0.9180                    119.0
# 25                                    0.9191                    166.0
# 26                                    0.8987                    421.0
# 27                                    0.8994                    946.0
# 28                                    0.9136                    620.0
# 29                                    0.9287                    551.0
# 30                                    0.8968                   1563.0
# 31                                    0.9309                    344.0
# 32                                    0.9253                     47.0
# 33                                    0.9167                     98.0
# 34                                    0.9174                     28.0
# 35                                    0.9168                    126.0
# 36                                    0.9133                     27.0
# 37                                    0.9349                    292.0
# 38                                    0.9385                    179.0
# 39                                    0.9206                    155.0
# 40                                    0.9457                   3093.0
# 41                                    0.9207                    305.0
# 42                                    0.9145                    184.0
# 43                                    0.9022                     51.0
# 44                                    0.9119                    235.0
# 45                                    0.9414                     90.0
# 46                                    0.9543                    737.0
# 47                                    0.9224                    172.0
# 48                                    0.9349                    226.0
# 49                                    0.9458                   1958.0
#
#     2020-2021 attendance rate  2019-2020 student count  \
# 0                      0.9294                 508346.0
# 1                      0.8155                   3916.0
# 2                      0.8946                  80365.0
# 3                      0.8861                 193706.0
# 4                      0.9299                  27507.0
# 5                      0.8927                 221213.0
# 6                      0.8948                  45413.0
# 7                      0.9483                  47260.0
# 8                      0.8931                  64200.0
# 9                      0.8975                 136953.0
# 10                     0.9523                 259933.0
# 11                     0.9616                 241610.0
# 12                     0.8996                 266736.0
# 13                     0.9680                    158.0
# 14                        NaN                      NaN
# 15                     0.9414                     37.0
# 16                     0.9699                    128.0
# 17                     0.9752                    108.0
# 18                     0.9513                     50.0
# 19                     0.8923                   2185.0
# 20                     0.8692                    411.0
# 21                     0.8657                   1312.0
# 22                     0.9234                    147.0
# 23                     0.8743                   1459.0
# 24                     0.8951                    129.0
# 25                     0.9105                    170.0
# 26                     0.8693                    434.0
# 27                     0.8798                    923.0
# 28                     0.9217                    658.0
# 29                     0.9389                    587.0
# 30                     0.8764                   1598.0
# 31                     0.9550                    348.0
# 32                     0.9573                     56.0
# 33                     0.9281                      NaN
# 34                     0.9424                      NaN
# 35                     0.9312                    130.0
# 36                     0.9408                     22.0
# 37                     0.9598                    298.0
# 38                     0.9686                    182.0
# 39                     0.9380                    166.0
# 40                     0.9621                   3138.0
# 41                     0.9309                    330.0
# 42                     0.9152                    243.0
# 43                     0.9356                     47.0
# 44                     0.9197                    290.0
# 45                     0.9601                    104.0
# 46                     0.9760                    755.0
# 47                     0.9299                    162.0
# 48                     0.9414                    215.0
# 49                     0.9620                   2006.0
#
#     2019-2020 attendance rate Reporting period Date update
# 0                      0.9479        June 2022  07/22/2022
# 1                      0.8884        June 2022  07/22/2022
# 2                      0.9277        June 2022  07/22/2022
# 3                      0.9314        June 2022  07/22/2022
# 4                      0.9518        June 2022  07/22/2022
# 5                      0.9340        June 2022  07/22/2022
# 6                      0.9389        June 2022  07/22/2022
# 7                      0.9559        June 2022  07/22/2022
# 8                      0.9401        June 2022  07/22/2022
# 9                      0.9362        June 2022  07/22/2022
# 10                     0.9543        June 2022  07/22/2022
# 11                     0.9606        June 2022  07/22/2022
# 12                     0.9361        June 2022  07/22/2022
# 13                     0.9502        June 2022  07/22/2022
# 14                        NaN        June 2022  07/22/2022
# 15                     0.9401        June 2022  07/22/2022
# 16                     0.9479        June 2022  07/22/2022
# 17                     0.9552        June 2022  07/22/2022
# 18                     0.9389        June 2022  07/22/2022
# 19                     0.9413        June 2022  07/22/2022
# 20                     0.9337        June 2022  07/22/2022
# 21                     0.9312        June 2022  07/22/2022
# 22                     0.9563        June 2022  07/22/2022
# 23                     0.9338        June 2022  07/22/2022
# 24                     0.9506        June 2022  07/22/2022
# 25                     0.9451        June 2022  07/22/2022
# 26                     0.9414        June 2022  07/22/2022
# 27                     0.9366        June 2022  07/22/2022
# 28                     0.9468        June 2022  07/22/2022
# 29                     0.9568        June 2022  07/22/2022
# 30                     0.9355        June 2022  07/22/2022
# 31                     0.9585        June 2022  07/22/2022
# 32                     0.9468        June 2022  07/22/2022
# 33                        NaN        June 2022  07/22/2022
# 34                        NaN        June 2022  07/22/2022
# 35                     0.9477        June 2022  07/22/2022
# 36                     0.9353        June 2022  07/22/2022
# 37                     0.9607        June 2022  07/22/2022
# 38                     0.9666        June 2022  07/22/2022
# 39                     0.9496        June 2022  07/22/2022
# 40                     0.9583        June 2022  07/22/2022
# 41                     0.9421        June 2022  07/22/2022
# 42                     0.9389        June 2022  07/22/2022
# 43                     0.9365        June 2022  07/22/2022
# 44                     0.9385        June 2022  07/22/2022
# 45                     0.9435        June 2022  07/22/2022
# 46                     0.9643        June 2022  07/22/2022
# 47                     0.9478        June 2022  07/22/2022
# 48                     0.9520        June 2022  07/22/2022
# 49                     0.9576        June 2022  07/22/2022

# %%
#Count number of districts
name_unique = data_set_df["District name"].value_counts()
name_count = len(name_unique)
name_count
# Out:
# 201

# %%
#List all columns
data_set_df.columns
# Out:
# Index(['District code', 'District name', 'Category', 'Student group',
#        '2021-2022 student count - year to date',
#        '2021-2022 attendance rate - year to date', '2020-2021 student count',
#        '2020-2021 attendance rate', '2019-2020 student count',
#        '2019-2020 attendance rate', 'Reporting period', 'Date update'],
#       dtype='object')

# %%
#Check for incomplete rows
data_set_df.count()
# Out:
# District code                               2019
# District name                               2019
# Category                                    1818
# Student group                               2019
# 2021-2022 student count - year to date      2019
# 2021-2022 attendance rate - year to date    2019
# 2020-2021 student count                     1963
# 2020-2021 attendance rate                   1963
# 2019-2020 student count                     1957
# 2019-2020 attendance rate                   1957
# Reporting period                            2019
# Date update                                 2019
# dtype: int64

# %%
data_set_df.dtypes
# Out:
# District code                                object
# District name                                object
# Category                                     object
# Student group                                object
# 2021-2022 student count - year to date        int64
# 2021-2022 attendance rate - year to date    float64
# 2020-2021 student count                     float64
# 2020-2021 attendance rate                   float64
# 2019-2020 student count                     float64
# 2019-2020 attendance rate                   float64
# Reporting period                             object
# Date update                                  object
# dtype: object

# %% [markdown]
# # Free and Reduced Meals

# %%
#Filter by free and reduced meals
fr_df = data_set_df.loc[(data_set_df["Student group"]=="Free/Reduced Price Meal Eligible") | (data_set_df["Student group"]=="All Students")]

fr_df.head()
# Out:
#    District code            District name            Category  \
# 0        00000CT              Connecticut                 NaN
# 5        00000CT              Connecticut  Free/Reduced Lunch
# 13       0010011  Andover School District                 NaN
# 15       0010011  Andover School District  Free/Reduced Lunch
# 19       0020011  Ansonia School District                 NaN
#
#                        Student group  2021-2022 student count - year to date  \
# 0                       All Students                                  500285
# 5   Free/Reduced Price Meal Eligible                                  198889
# 13                      All Students                                     161
# 15  Free/Reduced Price Meal Eligible                                      30
# 19                      All Students                                    2139
#
#     2021-2022 attendance rate - year to date  2020-2021 student count  \
# 0                                     0.9169                 496092.0
# 5                                     0.8901                 207111.0
# 13                                    0.9386                    144.0
# 15                                    0.9274                     31.0
# 19                                    0.9045                   2153.0
#
#     2020-2021 attendance rate  2019-2020 student count  \
# 0                      0.9294                 508346.0
# 5                      0.8927                 221213.0
# 13                     0.9680                    158.0
# 15                     0.9414                     37.0
# 19                     0.8923                   2185.0
#
#     2019-2020 attendance rate Reporting period Date update
# 0                      0.9479        June 2022  07/22/2022
# 5                      0.9340        June 2022  07/22/2022
# 13                     0.9502        June 2022  07/22/2022
# 15                     0.9401        June 2022  07/22/2022
# 19                     0.9413        June 2022  07/22/2022

# %%
#Filter by Free/Reduced Meals
frl_df = data_set_df.loc[(data_set_df["Student group"]=="Free/Reduced Price Meal Eligible")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
frl_df = frl_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date","2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_frl_df = pd.merge(all_df, frl_df, on="District name", how="right")

#Check counts
merged_frl_df.dtypes
# Out:
# District name                                object
# Student group_x                              object
# 2021-2022 student count - year to date_x      int64
# 2021-2022 attendance rate - year to date    float64
# Student group_y                              object
# 2021-2022 student count - year to date_y      int64
# dtype: object

# %%
merged_frl_df["Not FRL Count"] = (merged_frl_df["2021-2022 student count - year to date_x"]-merged_frl_df["2021-2022 student count - year to date_y"])
merged_frl_df.head()
# Out:
#              District name Student group_x  \
# 0              Connecticut    All Students
# 1  Andover School District    All Students
# 2  Ansonia School District    All Students
# 3  Ashford School District    All Students
# 4     Avon School District    All Students
#
#    2021-2022 student count - year to date_x  \
# 0                                    500285
# 1                                       161
# 2                                      2139
# 3                                       343
# 4                                      3057
#
#    2021-2022 attendance rate - year to date                   Student group_y  \
# 0                                    0.9169  Free/Reduced Price Meal Eligible
# 1                                    0.9386  Free/Reduced Price Meal Eligible
# 2                                    0.9045  Free/Reduced Price Meal Eligible
# 3                                    0.9309  Free/Reduced Price Meal Eligible
# 4                                    0.9457  Free/Reduced Price Meal Eligible
#
#    2021-2022 student count - year to date_y  Not FRL Count
# 0                                    198889         301396
# 1                                        30            131
# 2                                      1417            722
# 3                                       113            230
# 4                                       286           2771

# %%
#Calculate FRM percents of total
merged_frl_df["Percentage Free/Reduced Meal"]=merged_frl_df["2021-2022 student count - year to date_y"]/merged_frl_df['2021-2022 student count - year to date_x']
#Calculate Not FRM percents of total
merged_frl_df["Percentage Not Free/Reduced Meal"]=merged_frl_df["Not FRL Count"]/merged_frl_df['2021-2022 student count - year to date_x']

merged_frl_df.head()
# Out:
#              District name Student group_x  \
# 0              Connecticut    All Students
# 1  Andover School District    All Students
# 2  Ansonia School District    All Students
# 3  Ashford School District    All Students
# 4     Avon School District    All Students
#
#    2021-2022 student count - year to date_x  \
# 0                                    500285
# 1                                       161
# 2                                      2139
# 3                                       343
# 4                                      3057
#
#    2021-2022 attendance rate - year to date                   Student group_y  \
# 0                                    0.9169  Free/Reduced Price Meal Eligible
# 1                                    0.9386  Free/Reduced Price Meal Eligible
# 2                                    0.9045  Free/Reduced Price Meal Eligible
# 3                                    0.9309  Free/Reduced Price Meal Eligible
# 4                                    0.9457  Free/Reduced Price Meal Eligible
#
#    2021-2022 student count - year to date_y  Not FRL Count  \
# 0                                    198889         301396
# 1                                        30            131
# 2                                      1417            722
# 3                                       113            230
# 4                                       286           2771
#
#    Percentage Free/Reduced Meal  Percentage Not Free/Reduced Meal
# 0                      0.397551                          0.602449
# 1                      0.186335                          0.813665
# 2                      0.662459                          0.337541
# 3                      0.329446                          0.670554
# 4                      0.093556                          0.906444

# %%
#Check Counts
merged_frl_df.dtypes
# Out:
# District name                                object
# Student group_x                              object
# 2021-2022 student count - year to date_x      int64
# 2021-2022 attendance rate - year to date    float64
# Student group_y                              object
# 2021-2022 student count - year to date_y      int64
# Not FRL Count                                 int64
# Percentage Free/Reduced Meal                float64
# Percentage Not Free/Reduced Meal            float64
# dtype: object

# %%
#merged_con_df = merged_frl_df.loc[merged_frl_df["District name"]=="Connecticut"]
#merged_con_df

# %%
#Scatter plot for FR Meals
x_values = merged_frl_df["Percentage Free/Reduced Meal"]
y_values = merged_frl_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="lightseagreen", facecolors = "royalblue")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of Free/Reduced Meals')
plt.ylabel('Attendance Rate')
plt.title("Free/Reduced Meals Attendance Rates")
plt.annotate(line_eq,(0.15,0.875),fontsize=15, color = "red")
plt.savefig("Images/FRMAttenRate.png")
print(rvalue)
plt.show()
# Out:
# -0.6440007109406707

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.64

# %%
x_values = merged_frl_df["Percentage Not Free/Reduced Meal"]
y_values = merged_frl_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors = "lightslategray", facecolors = "firebrick")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of Not Free/Reduced Meals')
plt.ylabel('Attendance Rate')
plt.title("Not Free/Reduced Meals Attendance Rates")
plt.annotate(line_eq,(0.6,0.875),fontsize=15, color = "red")
plt.savefig("Images/NotFRMAttenRate.png")
print(rvalue)
plt.show()
# Out:
# 0.6440007109406707

# %% [markdown]
# # English Learners

# %%
#Filter by English learners
ell_df = data_set_df.loc[(data_set_df["Student group"]=="English Learners")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
ell_df = ell_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date", 
                 "2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_ell_df = pd.merge(all_df, ell_df, on="District name", how="right")

#Check counts
merged_ell_df.head()
# Out:
#              District name Student group_x  \
# 0              Connecticut    All Students
# 1  Ansonia School District    All Students
# 2     Avon School District    All Students
# 3   Berlin School District    All Students
# 4   Bethel School District    All Students
#
#    2021-2022 student count - year to date_x  \
# 0                                    500285
# 1                                      2139
# 2                                      3057
# 3                                      2613
# 4                                      3102
#
#    2021-2022 attendance rate - year to date   Student group_y  \
# 0                                    0.9169  English Learners
# 1                                    0.9045  English Learners
# 2                                    0.9457  English Learners
# 3                                    0.9341  English Learners
# 4                                    0.9375  English Learners
#
#    2021-2022 student count - year to date_y
# 0                                     43571
# 1                                       122
# 2                                        76
# 3                                        95
# 4                                       167

# %%
#Calculate ELL percents of total
merged_ell_df["Percentage ELL"]=merged_ell_df["2021-2022 student count - year to date_y"]\
/merged_ell_df['2021-2022 student count - year to date_x']

#Check Count
merged_ell_df.head()
# Out:
#              District name Student group_x  \
# 0              Connecticut    All Students
# 1  Ansonia School District    All Students
# 2     Avon School District    All Students
# 3   Berlin School District    All Students
# 4   Bethel School District    All Students
#
#    2021-2022 student count - year to date_x  \
# 0                                    500285
# 1                                      2139
# 2                                      3057
# 3                                      2613
# 4                                      3102
#
#    2021-2022 attendance rate - year to date   Student group_y  \
# 0                                    0.9169  English Learners
# 1                                    0.9045  English Learners
# 2                                    0.9457  English Learners
# 3                                    0.9341  English Learners
# 4                                    0.9375  English Learners
#
#    2021-2022 student count - year to date_y  Percentage ELL
# 0                                     43571        0.087092
# 1                                       122        0.057036
# 2                                        76        0.024861
# 3                                        95        0.036357
# 4                                       167        0.053836

# %%
#Calculate Percent not ELL
merged_ell_df["Not ELL Count"] = (merged_ell_df["2021-2022 student count - year to date_x"]-merged_ell_df["2021-2022 student count - year to date_y"])


#Calculate Not FRM percents of total
merged_ell_df["Percentage Not ELL"]=merged_ell_df["Not ELL Count"]/merged_ell_df['2021-2022 student count - year to date_x']

merged_ell_df.head()
# Out:
#              District name Student group_x  \
# 0              Connecticut    All Students
# 1  Ansonia School District    All Students
# 2     Avon School District    All Students
# 3   Berlin School District    All Students
# 4   Bethel School District    All Students
#
#    2021-2022 student count - year to date_x  \
# 0                                    500285
# 1                                      2139
# 2                                      3057
# 3                                      2613
# 4                                      3102
#
#    2021-2022 attendance rate - year to date   Student group_y  \
# 0                                    0.9169  English Learners
# 1                                    0.9045  English Learners
# 2                                    0.9457  English Learners
# 3                                    0.9341  English Learners
# 4                                    0.9375  English Learners
#
#    2021-2022 student count - year to date_y  Percentage ELL  Not ELL Count  \
# 0                                     43571        0.087092         456714
# 1                                       122        0.057036           2017
# 2                                        76        0.024861           2981
# 3                                        95        0.036357           2518
# 4                                       167        0.053836           2935
#
#    Percentage Not ELL
# 0            0.912908
# 1            0.942964
# 2            0.975139
# 3            0.963643
# 4            0.946164

# %%
#Plot ELL Attendance Rates
x_values = merged_ell_df["Percentage ELL"]
y_values = merged_ell_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="darkslategray", facecolors="lightskyblue")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of Students ELL')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.15,0.86),fontsize=15, color = "red")
plt.title("English Learners Attendance Rates")
print(rvalue)

#Save Figure
plt.savefig("Images/ScatterELL.png")


plt.show()
# Out:
# -0.5324713816396521

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.53

# %%
#Plot ELL Attendance Rates
x_values = merged_ell_df["Percentage Not ELL"]
y_values = merged_ell_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="darkslategray", facecolors="darkkhaki")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of Students Not ELL')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.70,0.93),fontsize=15, color = "red")
plt.title("Non English Learners Attendance Rates")
print(rvalue)

#Save Figure
plt.savefig("Images/ScatterNotELL.png")


plt.show()
# Out:
# 0.5324713816396519

# %% [markdown]
# # Students with Disabilities

# %%
#Filter by Student with Disabilites
dis_df = data_set_df.loc[(data_set_df["Student group"]=="Students With Disabilities")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
dis_df = dis_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date", "2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_dis_df = pd.merge(all_df, dis_df, on="District name", how="right")

#Check counts
merged_dis_df.count()
# Out:
# District name                               190
# Student group_x                             190
# 2021-2022 student count - year to date_x    190
# 2021-2022 attendance rate - year to date    190
# Student group_y                             190
# 2021-2022 student count - year to date_y    190
# dtype: int64

# %%
#Calculate Disabilites percents of total
merged_dis_df["Percentage Disabilities"]=merged_dis_df["2021-2022 student count - year to date_y"]/merged_dis_df['2021-2022 student count - year to date_x']
#Check Count
merged_dis_df.count()
# Out:
# District name                               190
# Student group_x                             190
# 2021-2022 student count - year to date_x    190
# 2021-2022 attendance rate - year to date    190
# Student group_y                             190
# 2021-2022 student count - year to date_y    190
# Percentage Disabilities                     190
# dtype: int64

# %%
x_values = merged_dis_df["Percentage Disabilities"]
y_values = merged_dis_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="sienna", facecolors="darkkhaki")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of with Disabilities')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.2,0.835),fontsize=15, color = "red")
plt.title("Students with Disabilities Attendance")
print(rvalue)

plt.savefig("Images/ScatterDis.png")

plt.show()
# Out:
# -0.46677539240579297

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.47

# %%
#Calculate Percent not Dis
merged_dis_df["Not Dis Count"] = (merged_dis_df["2021-2022 student count - year to date_x"]-merged_dis_df["2021-2022 student count - year to date_y"])


#Calculate Not Dis percents of total
merged_dis_df["Percentage Not Dis"]=merged_dis_df["Not Dis Count"]/merged_dis_df['2021-2022 student count - year to date_x']

merged_dis_df.head()
# Out:
#              District name Student group_x  \
# 0              Connecticut    All Students
# 1  Andover School District    All Students
# 2  Ansonia School District    All Students
# 3  Ashford School District    All Students
# 4     Avon School District    All Students
#
#    2021-2022 student count - year to date_x  \
# 0                                    500285
# 1                                       161
# 2                                      2139
# 3                                       343
# 4                                      3057
#
#    2021-2022 attendance rate - year to date             Student group_y  \
# 0                                    0.9169  Students With Disabilities
# 1                                    0.9386  Students With Disabilities
# 2                                    0.9045  Students With Disabilities
# 3                                    0.9309  Students With Disabilities
# 4                                    0.9457  Students With Disabilities
#
#    2021-2022 student count - year to date_y  Percentage Disabilities  \
# 0                                     78417                 0.156745
# 1                                        23                 0.142857
# 2                                       369                 0.172511
# 3                                        46                 0.134111
# 4                                       324                 0.105986
#
#    Not Dis Count  Percentage Not Dis
# 0         421868            0.843255
# 1            138            0.857143
# 2           1770            0.827489
# 3            297            0.865889
# 4           2733            0.894014

# %%
#Plot ELL Attendance Rates
x_values = merged_dis_df["Percentage Not Dis"]
y_values = merged_dis_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="silver", facecolors="seagreen")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of Students No Disabilities')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.70,0.93),fontsize=15, color = "red")
plt.title("No Disabilities Students Attendance Rates")
print(rvalue)

#Save Figure
plt.savefig("Images/ScatterNotDis.png")


plt.show()
# Out:
# 0.46677539240579297

# %% [markdown]
# # Student with High Needs

# %%
#Filter by Student with High Needs
needs_df = data_set_df.loc[(data_set_df["Student group"]=="Students With High Needs")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
needs_df = needs_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date", "2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_needs_df = pd.merge(all_df, needs_df, on="District name", how="right")

#Check counts
merged_needs_df.count()
# Out:
# District name                               197
# Student group_x                             197
# 2021-2022 student count - year to date_x    197
# 2021-2022 attendance rate - year to date    197
# Student group_y                             197
# 2021-2022 student count - year to date_y    197
# dtype: int64

# %%
#Calculate High Needs percents of total
merged_needs_df["Percentage High Needs"]=merged_needs_df["2021-2022 student count - year to date_y"]/merged_needs_df['2021-2022 student count - year to date_x']
#Check Count
merged_needs_df.count()
# Out:
# District name                               197
# Student group_x                             197
# 2021-2022 student count - year to date_x    197
# 2021-2022 attendance rate - year to date    197
# Student group_y                             197
# 2021-2022 student count - year to date_y    197
# Percentage High Needs                       197
# dtype: int64

# %%
#High Needs Scatter Plot
x_values = merged_needs_df["Percentage High Needs"]
y_values = merged_needs_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="darkslategray", facecolors="forestgreen")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of with High Needs')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.15,0.88),fontsize=15, color = "red")
plt.title("Students with High Needs Attendance Rates")
print(rvalue)
plt.savefig("Images/ScatterNeeds.png")
plt.show()
# Out:
# -0.719825743438532

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.72

# %%
#Calculate Percent not High Needs
merged_needs_df["Not High Needs Count"] = (merged_needs_df["2021-2022 student count - year to date_x"]-merged_needs_df["2021-2022 student count - year to date_y"])


#Calculate Not High Needs percents of total
merged_needs_df["Percentage Not High Needs"]=merged_needs_df["Not High Needs Count"]/merged_needs_df['2021-2022 student count - year to date_x']

merged_needs_df.head()
# Out:
#              District name Student group_x  \
# 0              Connecticut    All Students
# 1  Andover School District    All Students
# 2  Ansonia School District    All Students
# 3  Ashford School District    All Students
# 4     Avon School District    All Students
#
#    2021-2022 student count - year to date_x  \
# 0                                    500285
# 1                                       161
# 2                                      2139
# 3                                       343
# 4                                      3057
#
#    2021-2022 attendance rate - year to date           Student group_y  \
# 0                                    0.9169  Students With High Needs
# 1                                    0.9386  Students With High Needs
# 2                                    0.9045  Students With High Needs
# 3                                    0.9309  Students With High Needs
# 4                                    0.9457  Students With High Needs
#
#    2021-2022 student count - year to date_y  Percentage High Needs  \
# 0                                    248239               0.496195
# 1                                        48               0.298137
# 2                                      1545               0.722300
# 3                                       145               0.422741
# 4                                       587               0.192018
#
#    Not High Needs Count  Percentage Not High Needs
# 0                252046                   0.503805
# 1                   113                   0.701863
# 2                   594                   0.277700
# 3                   198                   0.577259
# 4                  2470                   0.807982

# %%
#Plot ELL Attendance Rates
x_values = merged_needs_df["Percentage Not High Needs"]
y_values = merged_needs_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="silver", facecolors="palevioletred")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of Students Without High Needs')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.6,0.88),fontsize=15, color = "red")
plt.title("Students without High Needs Attendance Rates")
print(rvalue)

#Save Figure
plt.savefig("Images/ScatterNotNeeds.png")


plt.show()
# Out:
# 0.719825743438532

# %% [markdown]
# # Students Race = Black or African American

# %%
#Filter by Student Race = Black of African American
black_df = data_set_df.loc[(data_set_df["Student group"]=="Black or African American")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
black_df = black_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date", "2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_black_df = pd.merge(all_df, black_df, on="District name", how="right")

#Check counts
merged_black_df.count()
# Out:
# District name                               128
# Student group_x                             128
# 2021-2022 student count - year to date_x    128
# 2021-2022 attendance rate - year to date    128
# Student group_y                             128
# 2021-2022 student count - year to date_y    128
# dtype: int64

# %%
#Calculate Black/African American percents of total
merged_black_df["Percentage Black or African American"]=merged_black_df["2021-2022 student count - year to date_y"]/merged_black_df['2021-2022 student count - year to date_x']
#Check Count
merged_black_df.count()
# Out:
# District name                               128
# Student group_x                             128
# 2021-2022 student count - year to date_x    128
# 2021-2022 attendance rate - year to date    128
# Student group_y                             128
# 2021-2022 student count - year to date_y    128
# Percentage Black or African American        128
# dtype: int64

# %%
#Balck Attendance Rates
x_values = merged_black_df["Percentage Black or African American"]
y_values = merged_black_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="darkgray", facecolors="darkblue")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent Black and African American')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.15,0.86),fontsize=15, color = "red")
plt.title("Black Students Attendance Rates")
print(rvalue)
plt.savefig("Images/ScatterBlack.png")
plt.show()
# Out:
# -0.4734319890187277

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.47

# %% [markdown]
# # Students Race = Hispanic/Latino of any race

# %%
#Filter by Student Race = Hispanic/Latino of any race
his_df = data_set_df.loc[(data_set_df["Student group"]=="Hispanic/Latino of any race")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
his_df = his_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date", "2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_his_df = pd.merge(all_df, his_df, on="District name", how="right")

#Check counts
merged_his_df.count()
# Out:
# District name                               168
# Student group_x                             168
# 2021-2022 student count - year to date_x    168
# 2021-2022 attendance rate - year to date    168
# Student group_y                             168
# 2021-2022 student count - year to date_y    168
# dtype: int64

# %%
#Calculate Hispanic/Latino of any race percents of total
merged_his_df["Percentage Hispanic/Latino of any race"]=merged_his_df["2021-2022 student count - year to date_y"]/merged_his_df['2021-2022 student count - year to date_x']
#Check Count
merged_his_df.count()
# Out:
# District name                               168
# Student group_x                             168
# 2021-2022 student count - year to date_x    168
# 2021-2022 attendance rate - year to date    168
# Student group_y                             168
# 2021-2022 student count - year to date_y    168
# Percentage Hispanic/Latino of any race      168
# dtype: int64

# %%
#Hispanic Attendance Graph
x_values = merged_his_df["Percentage Hispanic/Latino of any race"]
y_values = merged_his_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="dimgrey", facecolors="mediumseagreen")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent of Hispanic/Latino')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.15,0.855),fontsize=15, color = "red")
plt.title("Hispanic/Latino Students Attendance Rates")
print(rvalue)
plt.savefig("Images/ScatterHisp.png")

plt.show()
# Out:
# -0.5042716980200688

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.5

# %% [markdown]
# # Students Race = White

# %%
#Filter by Student Race = White
white_df = data_set_df.loc[(data_set_df["Student group"]=="White")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
white_df = white_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date", "2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_white_df = pd.merge(all_df, white_df, on="District name", how="right")

#Check counts
merged_white_df.count()
# Out:
# District name                               182
# Student group_x                             182
# 2021-2022 student count - year to date_x    182
# 2021-2022 attendance rate - year to date    182
# Student group_y                             182
# 2021-2022 student count - year to date_y    182
# dtype: int64

# %%
#Calculate White of any race percents of total
merged_white_df["Percentage White"]=merged_white_df["2021-2022 student count - year to date_y"]/merged_white_df['2021-2022 student count - year to date_x']

#Check Count
merged_white_df.count()
# Out:
# District name                               182
# Student group_x                             182
# 2021-2022 student count - year to date_x    182
# 2021-2022 attendance rate - year to date    182
# Student group_y                             182
# 2021-2022 student count - year to date_y    182
# Percentage White                            182
# dtype: int64

# %%
#White Students Attendance Graph
x_values = merged_white_df["Percentage White"]
y_values = merged_white_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="darkslategray", facecolors="mediumvioletred")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent White')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.15,0.86),fontsize=15, color = "red")
plt.title("White Students Attendance Rates")
print(rvalue)
plt.savefig("Images/ScatterWhite.png")
plt.show()
# Out:
# 0.5127319750155351

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.51

# %% [markdown]
# # Students All Other Races

# %%
#Filter by Student Race = All Other
other_df = data_set_df.loc[(data_set_df["Student group"]=="All other races")]
all_df = data_set_df.loc[(data_set_df["Student group"]=="All Students")]


#Limit data frame again
other_df = other_df[["District name", "Student group", "2021-2022 student count - year to date"]]
all_df = all_df[["District name", "Student group", "2021-2022 student count - year to date", "2021-2022 attendance rate - year to date"]]

#Merge Data sets right
merged_other_df = pd.merge(all_df, other_df, on="District name", how="right")

#Check counts
merged_other_df.count()
# Out:
# District name                               121
# Student group_x                             121
# 2021-2022 student count - year to date_x    121
# 2021-2022 attendance rate - year to date    121
# Student group_y                             121
# 2021-2022 student count - year to date_y    121
# dtype: int64

# %%
#Calculate All Races of any race percents of total
merged_other_df["Percentage Other Races"]=merged_other_df["2021-2022 student count - year to date_y"]/merged_other_df['2021-2022 student count - year to date_x']

#Check Count
merged_other_df.count()
# Out:
# District name                               121
# Student group_x                             121
# 2021-2022 student count - year to date_x    121
# 2021-2022 attendance rate - year to date    121
# Student group_y                             121
# 2021-2022 student count - year to date_y    121
# Percentage Other Races                      121
# dtype: int64

# %%
#All Other Races Attendance Graphs
x_values = merged_other_df["Percentage Other Races"]
y_values = merged_other_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="darkslategray", facecolors="plum")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Percent Other Races')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(0.18,0.9),fontsize=15, color = "red")
plt.title("All Other Races Attendance")
print(rvalue)
plt.savefig("Images/ScatterOtherRace.png")
plt.show()
# Out:
# 0.22706892629570416

# %%
correlation = st.pearsonr(x_values, y_values)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.23

# %%
# Total number of students compared to attendance rate
total_df = data_set_df.loc[data_set_df["Student group"]=="All Students"]
total_df = total_df[["District name", "Student group","2021-2022 student count - year to date", "2021-2022 attendance rate - year to date"]]
total_df = total_df.drop(0)
total_df
# Out:
#                                           District name Student group  \
# 13                              Andover School District  All Students
# 19                              Ansonia School District  All Students
# 31                              Ashford School District  All Students
# 40                                 Avon School District  All Students
# 52                          Barkhamsted School District  All Students
# ...                                                 ...           ...
# 1972                         Unified School District #2  All Students
# 1977  Connecticut Technical Education and Career System  All Students
# 1990                      Norwich Free Academy District  All Students
# 2002                        The Gilbert School District  All Students
# 2011                     The Woodstock Academy District  All Students
#
#       2021-2022 student count - year to date  \
# 13                                       161
# 19                                      2139
# 31                                       343
# 40                                      3057
# 52                                       199
# ...                                      ...
# 1972                                      78
# 1977                                   11138
# 1990                                    2068
# 2002                                     421
# 2011                                    1060
#
#       2021-2022 attendance rate - year to date
# 13                                      0.9386
# 19                                      0.9045
# 31                                      0.9309
# 40                                      0.9457
# 52                                      0.9305
# ...                                        ...
# 1972                                    0.9202
# 1977                                    0.8985
# 1990                                    0.8940
# 2002                                    0.8901
# 2011                                    0.9288
#
# [200 rows x 4 columns]

# %%
#Scatter plot of count to attendance rate
#All Other Races Attendance Graphs
x_values = total_df["2021-2022 student count - year to date"]
y_values = total_df["2021-2022 attendance rate - year to date"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, edgecolors="darkslategray", facecolors="plum")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Total number of Students')
plt.ylabel('Attendance Rate')
plt.annotate(line_eq,(7500,0.85),fontsize=15, color = "red")
plt.title("Total Number of Students vs Attendance Rate")
print(rvalue)
plt.savefig("Images/ScatterAttendanceTotal.png")
plt.show()
# Out:
# -0.22328004076937047
